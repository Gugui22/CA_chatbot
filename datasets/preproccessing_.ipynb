# %%
import pandas as pd
import numpy as np

# %%
import os

# set path
data_path = os.path.abspath('') + "/raw/details.xlsx"

df_distri_loc_area_repre = pd.read_excel(data_path, sheet_name = "Distri x loc x area x repre")
df_representantes = pd.read_excel(data_path, sheet_name = "Representantes")

# %% [markdown]
# ### Exploracion datos

# %%
df_representantes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69 entries, 0 to 68
# Data columns (total 22 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Distrito        58 non-null     object
#  1   Area_Actuacion  58 non-null     object
#  2   Nombre          58 non-null     object
#  3   RTV/DTM         58 non-null     object
#  4   e-Mail          58 non-null     object
#  5   Celular         57 non-null     object
#  6   Unnamed: 6      0 non-null      float64
#  7   Unnamed: 7      0 non-null      float64
#  8   Unnamed: 8      0 non-null      float64
#  9   Unnamed: 9      0 non-null      float64
#  10  Unnamed: 10     0 non-null      float64
#  11  Unnamed: 11     7 non-null      object
#  12  Unnamed: 12     1 non-null      object
#  13  Unnamed: 13     7 non-null      object
#  14  Unnamed: 14     7 non-null      object
#  15  Unnamed: 15     7 non-null      object
#  16  Unnamed: 16     7 non-null      object
#  17  Unnamed: 17     2 non-null      object
#  18  Unnamed: 18     2 non-null      object
#  19  Unnamed: 19     7 non-null      object
#  20  Unnamed: 20     7 non-null      object
#  21  Unnamed: 21     7 non-null      object
# dtypes: float64(5), object(17)
# memory usage: 12.0+ KB

# %%
# Eliminamos columnas rotas

column_index_to_stop = 6  # Adjust this to the desired column index
columns_to_delete = df_representantes.columns.tolist()[column_index_to_stop:]

df_representantes = df_representantes.drop(columns=columns_to_delete, axis=1)

# %%
df_representantes.shape
# Out:
# (69, 6)

# %%
df_representantes.head()
# Out:
#   Distrito                              Area_Actuacion  \
# 0  NOA-NEA                              SANTA FE NORTE
# 1  NOA-NEA         TUCUMAN, CATAMARCA Y SANTIAGO OESTE
# 2  NOA-NEA  CORRIENTES, MISIONES Y NORTE DE ENTRE RIOS
# 3  NOA-NEA                               SALTA Y JUJUY
# 4  NOA-NEA                              CHACO SUROESTE
#
#                            Nombre RTV/DTM                          e-Mail   \
# 0                         VACANTE     RTV                          VACANTE
# 1                FEDERICO CARRIZO     RTV        federico.carrizo@basf.com
# 2  TERENZIO VILLARRAZA FAVIO JOSE     RTV          favio.terenzio@basf.com
# 3          CAZADO RODRIGO GABRIEL     RTV  rodrigo-gabriel.cazado@basf.com
# 4            BESTANGA IVAN NAHUEL     RTV           ivan.bestanga@basf.com
#
#             Celular
# 0            ZZZZZZ
# 1  +54 938 15536044
# 2  +54 937 94335022
# 3  +54 938 77408214
# 4  +54 937 31542623

# %% [markdown]
# ------------------------------------------------

# %%
df_distri_loc_area_repre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 320 entries, 0 to 319
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   DISTRIBUIDOR BASF          320 non-null    object
#  1   Provincia                  320 non-null    object
#  2   localidad                  320 non-null    object
#  3   Departamento / Partido     318 non-null    object
#  4   pedania                    318 non-null    object
#  5   distrito                   320 non-null    object
#  6   ÁREA ACTUACION RTV NOMBRE  320 non-null    object
#  7   NOMBRE RTV                 317 non-null    object
#  8   AREA ACTUACION DTM         319 non-null    object
#  9   NOMBRE DTM                 317 non-null    object
# dtypes: object(10)
# memory usage: 25.1+ KB

# %%
df_RTV = df_distri_loc_area_repre[df_distri_loc_area_repre.columns.drop(list(df_distri_loc_area_repre.filter(regex='DTM')))]
df_DTM = df_distri_loc_area_repre[df_distri_loc_area_repre.columns.drop(list(df_distri_loc_area_repre.filter(regex='RTV')))]

# %%
df_DTM.head()
# Out:
#                     DISTRIBUIDOR BASF   Provincia                  localidad  \
# 0                            SINER SA    SANTA FE                      CERES
# 1                             FG AGRO  ENTRE RIOS                  CONCORDIA
# 2                MAS AGRO CENTRO S.A.     CORDOBA  SANTA ROSA DE RIO PRIMERO
# 3          TERRA VERDE AGROINSUMOS SA     CORDOBA                VILLA MARIA
# 4  UNION AGRICOLA DE AVELLANEDA COOP.    SANTA FE            GUADALUPE NORTE
#
#   Departamento / Partido          pedania distrito AREA ACTUACION DTM  \
# 0          SAN CRISTOBAL            CERES  NOA-NEA     SANTA FE NORTE
# 1              CONCORDIA        CONCORDIA  NOA-NEA            LITORAL
# 2            RIO PRIMERO       SANTA SOSA      PHC      CORDOBA NORTE
# 3     GENERAL SAN MARTIN      VILLA MARIA      PHC     CORDOBA CENTRO
# 4       GENERAL OBLIGADO  GUADALUPE NORTE  NOA-NEA     SANTA FE NORTE
#
#        NOMBRE DTM
# 0  MAURICIO MUCHUT
# 1  MAURICIO MUCHUT
# 2      DANIEL ULLA
# 3  SORAYA MARITANO
# 4  MAURICIO MUCHUT

# %%
df_RTV.head()
# Out:
#                     DISTRIBUIDOR BASF   Provincia                  localidad  \
# 0                            SINER SA    SANTA FE                      CERES
# 1                             FG AGRO  ENTRE RIOS                  CONCORDIA
# 2                MAS AGRO CENTRO S.A.     CORDOBA  SANTA ROSA DE RIO PRIMERO
# 3          TERRA VERDE AGROINSUMOS SA     CORDOBA                VILLA MARIA
# 4  UNION AGRICOLA DE AVELLANEDA COOP.    SANTA FE            GUADALUPE NORTE
#
#   Departamento / Partido          pedania distrito ÁREA ACTUACION RTV NOMBRE  \
# 0          SAN CRISTOBAL            CERES  NOA-NEA            SANTA FE NORTE
# 1              CONCORDIA        CONCORDIA  NOA-NEA                   LITORAL
# 2            RIO PRIMERO       SANTA SOSA      PHC             CORDOBA NORTE
# 3     GENERAL SAN MARTIN      VILLA MARIA      PHC            CORDOBA CENTRO
# 4       GENERAL OBLIGADO  GUADALUPE NORTE  NOA-NEA            SANTA FE NORTE
#
#                   NOMBRE RTV
# 0  FAVIO TERENZIO VILLARRAZA
# 1  FAVIO TERENZIO VILLARRAZA
# 2            IGNACIO REYNOSO
# 3            EVELYN BISCHOFF
# 4  FAVIO TERENZIO VILLARRAZA

# %% [markdown]
# ## Agregrar informacion de contacto

# %% [markdown]
# **Objetivo:** traer la informacion de contacto del df_representantes a el df_distri_loc_area_repre.
#
# Pasos:
# * Separar columna de nombres en nombre y apellido en el df_representates.
# * Separar columna de nombres en nombre y apellido en df_rtv y df_dtm
# * tratar de unir

# %%
# Funcion para generar split de apellidos
def split_name(name):
    
    words = name.split()
    if len(words) == 2:
        # If there are exactly two words, split by the first space
        return words[0], words[1]
    elif len(words) > 2:
        # return first and last word
        return words[0], words[-1]
        #return ' '.join(words[:2]), ' '.join(words[2:]) # If there are more than two words, split by the second space
    else:
        # If there is only one word (just in case), return the word and an empty string
        return words[0], ''

# %% [markdown]
# ### Representates

# %%
df_representantes[df_representantes['Nombre'].apply(lambda x: isinstance(x, float))]
# Out:
#    Distrito Area_Actuacion Nombre RTV/DTM e-Mail  Celular
# 58      NaN            NaN    NaN     NaN     NaN     NaN
# 59      NaN            NaN    NaN     NaN     NaN     NaN
# 60      NaN            NaN    NaN     NaN     NaN     NaN
# 61      NaN            NaN    NaN     NaN     NaN     NaN
# 62      NaN            NaN    NaN     NaN     NaN     NaN
# 63      NaN            NaN    NaN     NaN     NaN     NaN
# 64      NaN            NaN    NaN     NaN     NaN     NaN
# 65      NaN            NaN    NaN     NaN     NaN     NaN
# 66      NaN            NaN    NaN     NaN     NaN     NaN
# 67      NaN            NaN    NaN     NaN     NaN     NaN
# 68      NaN            NaN    NaN     NaN     NaN     NaN

# %%
df_representantes.dropna(axis = 0, inplace = True)

# %%
# Separamos en nombre y apellido los representates en 'Representates'
df_representantes[['apellido', 'nombre']] = df_representantes['Nombre'].apply(split_name).apply(pd.Series)
df_representantes.head()
# Out:
#   Distrito                              Area_Actuacion  \
# 0  NOA-NEA                              SANTA FE NORTE
# 1  NOA-NEA         TUCUMAN, CATAMARCA Y SANTIAGO OESTE
# 2  NOA-NEA  CORRIENTES, MISIONES Y NORTE DE ENTRE RIOS
# 3  NOA-NEA                               SALTA Y JUJUY
# 4  NOA-NEA                              CHACO SUROESTE
#
#                            Nombre RTV/DTM                          e-Mail   \
# 0                         VACANTE     RTV                          VACANTE
# 1                FEDERICO CARRIZO     RTV        federico.carrizo@basf.com
# 2  TERENZIO VILLARRAZA FAVIO JOSE     RTV          favio.terenzio@basf.com
# 3          CAZADO RODRIGO GABRIEL     RTV  rodrigo-gabriel.cazado@basf.com
# 4            BESTANGA IVAN NAHUEL     RTV           ivan.bestanga@basf.com
#
#             Celular  apellido   nombre
# 0            ZZZZZZ   VACANTE
# 1  +54 938 15536044  FEDERICO  CARRIZO
# 2  +54 937 94335022  TERENZIO     JOSE
# 3  +54 938 77408214    CAZADO  GABRIEL
# 4  +54 937 31542623  BESTANGA   NAHUEL

# %% [markdown]
# ---

# %% [markdown]
# ### df_rtv // df_dtm

# %%
df_RTV.dropna(axis = 0, inplace = True)
df_DTM.dropna(axis = 0, inplace = True)
# Out:
# /tmp/ipykernel_415729/3402535792.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_RTV.dropna(axis = 0, inplace = True)
# /tmp/ipykernel_415729/3402535792.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_DTM.dropna(axis = 0, inplace = True)

# %%
df_RTV[['nombre', 'apellido']] = df_RTV['NOMBRE RTV']. apply(split_name).apply(pd.Series)
# Out:
# /tmp/ipykernel_415729/3548748097.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_RTV[['nombre', 'apellido']] = df_RTV['NOMBRE RTV']. apply(split_name).apply(pd.Series)
# /tmp/ipykernel_415729/3548748097.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_RTV[['nombre', 'apellido']] = df_RTV['NOMBRE RTV']. apply(split_name).apply(pd.Series)

# %%
df_RTV.head()
# Out:
#                     DISTRIBUIDOR BASF   Provincia                  localidad  \
# 0                            SINER SA    SANTA FE                      CERES
# 1                             FG AGRO  ENTRE RIOS                  CONCORDIA
# 2                MAS AGRO CENTRO S.A.     CORDOBA  SANTA ROSA DE RIO PRIMERO
# 3          TERRA VERDE AGROINSUMOS SA     CORDOBA                VILLA MARIA
# 4  UNION AGRICOLA DE AVELLANEDA COOP.    SANTA FE            GUADALUPE NORTE
#
#   Departamento / Partido          pedania distrito ÁREA ACTUACION RTV NOMBRE  \
# 0          SAN CRISTOBAL            CERES  NOA-NEA            SANTA FE NORTE
# 1              CONCORDIA        CONCORDIA  NOA-NEA                   LITORAL
# 2            RIO PRIMERO       SANTA SOSA      PHC             CORDOBA NORTE
# 3     GENERAL SAN MARTIN      VILLA MARIA      PHC            CORDOBA CENTRO
# 4       GENERAL OBLIGADO  GUADALUPE NORTE  NOA-NEA            SANTA FE NORTE
#
#                   NOMBRE RTV   nombre    apellido
# 0  FAVIO TERENZIO VILLARRAZA    FAVIO  VILLARRAZA
# 1  FAVIO TERENZIO VILLARRAZA    FAVIO  VILLARRAZA
# 2            IGNACIO REYNOSO  IGNACIO     REYNOSO
# 3            EVELYN BISCHOFF   EVELYN    BISCHOFF
# 4  FAVIO TERENZIO VILLARRAZA    FAVIO  VILLARRAZA

# %%
df_DTM[['nombre', 'apellido']] = df_DTM['NOMBRE DTM ']. apply(split_name).apply(pd.Series)
# Out:
# /tmp/ipykernel_415729/2285158550.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_DTM[['nombre', 'apellido']] = df_DTM['NOMBRE DTM ']. apply(split_name).apply(pd.Series)
# /tmp/ipykernel_415729/2285158550.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_DTM[['nombre', 'apellido']] = df_DTM['NOMBRE DTM ']. apply(split_name).apply(pd.Series)

# %%
df_DTM.head()
# Out:
#                     DISTRIBUIDOR BASF   Provincia                  localidad  \
# 0                            SINER SA    SANTA FE                      CERES
# 1                             FG AGRO  ENTRE RIOS                  CONCORDIA
# 2                MAS AGRO CENTRO S.A.     CORDOBA  SANTA ROSA DE RIO PRIMERO
# 3          TERRA VERDE AGROINSUMOS SA     CORDOBA                VILLA MARIA
# 4  UNION AGRICOLA DE AVELLANEDA COOP.    SANTA FE            GUADALUPE NORTE
#
#   Departamento / Partido          pedania distrito AREA ACTUACION DTM  \
# 0          SAN CRISTOBAL            CERES  NOA-NEA     SANTA FE NORTE
# 1              CONCORDIA        CONCORDIA  NOA-NEA            LITORAL
# 2            RIO PRIMERO       SANTA SOSA      PHC      CORDOBA NORTE
# 3     GENERAL SAN MARTIN      VILLA MARIA      PHC     CORDOBA CENTRO
# 4       GENERAL OBLIGADO  GUADALUPE NORTE  NOA-NEA     SANTA FE NORTE
#
#        NOMBRE DTM     nombre  apellido
# 0  MAURICIO MUCHUT  MAURICIO    MUCHUT
# 1  MAURICIO MUCHUT  MAURICIO    MUCHUT
# 2      DANIEL ULLA    DANIEL      ULLA
# 3  SORAYA MARITANO    SORAYA  MARITANO
# 4  MAURICIO MUCHUT  MAURICIO    MUCHUT

# %% [markdown]
# -----

# %% [markdown]
# ### Union

# %%
df_representantes.head()
# Out:
#   Distrito                              Area_Actuacion  \
# 0  NOA-NEA                              SANTA FE NORTE
# 1  NOA-NEA         TUCUMAN, CATAMARCA Y SANTIAGO OESTE
# 2  NOA-NEA  CORRIENTES, MISIONES Y NORTE DE ENTRE RIOS
# 3  NOA-NEA                               SALTA Y JUJUY
# 4  NOA-NEA                              CHACO SUROESTE
#
#                            Nombre RTV/DTM                          e-Mail   \
# 0                         VACANTE     RTV                          VACANTE
# 1                FEDERICO CARRIZO     RTV        federico.carrizo@basf.com
# 2  TERENZIO VILLARRAZA FAVIO JOSE     RTV          favio.terenzio@basf.com
# 3          CAZADO RODRIGO GABRIEL     RTV  rodrigo-gabriel.cazado@basf.com
# 4            BESTANGA IVAN NAHUEL     RTV           ivan.bestanga@basf.com
#
#             Celular  apellido   nombre
# 0            ZZZZZZ   VACANTE
# 1  +54 938 15536044  FEDERICO  CARRIZO
# 2  +54 937 94335022  TERENZIO     JOSE
# 3  +54 938 77408214    CAZADO  GABRIEL
# 4  +54 937 31542623  BESTANGA   NAHUEL

# %%
df_representantes_RTV = df_representantes.loc[df_representantes["RTV/DTM"] == "RTV"]
df_representantes_DTM = df_representantes.loc[~(df_representantes["RTV/DTM"] == "RTV")]

# %% [markdown]
# #### RTV

# %% [markdown]
# ##### Exact Match

# %%
merged_df = pd.merge(df_RTV, df_representantes_RTV, on=['nombre', 'apellido'], how='left')

# %%
merged_df[merged_df['Nombre'].isnull()]
# Out:
#                       DISTRIBUIDOR BASF     Provincia        localidad  \
# 0                              SINER SA      SANTA FE            CERES
# 1                               FG AGRO    ENTRE RIOS        CONCORDIA
# 4    UNION AGRICOLA DE AVELLANEDA COOP.      SANTA FE  GUADALUPE NORTE
# 5               BAYA CASAL ENRIQUE M SA    ENTRE RIOS        GUALEGUAY
# 6                        CAMEL AGRO SRL  BUENOS AIRES            ROJAS
# ..                                  ...           ...              ...
# 306                      QUINTAL AGROSS    ENTRE RIOS           PARANA
# 307                   AZUL JACARANDA SA  BUENOS AIRES          PEHUAJO
# 308                           AGRONORTE      SANTA FE    SAN FRANCISCO
# 309                             FG AGRO    ENTRE RIOS     SAN SALVADOR
# 310              LARTIRIGOYEN  CIA S.A.      LA PAMPA          CATRILO
#
#     Departamento / Partido          pedania distrito  \
# 0            SAN CRISTOBAL            CERES  NOA-NEA
# 1                CONCORDIA        CONCORDIA  NOA-NEA
# 4         GENERAL OBLIGADO  GUADALUPE NORTE  NOA-NEA
# 5                GUALEGUAY        GUALEGUAY      PHN
# 6                    ROJAS            ROJAS      PHS
# ..                     ...              ...      ...
# 306                 PARANA           PARANA      PHN
# 307                PEHUAJO          PEHUAJO      PHS
# 308            CASTELLANOS    BAUER Y SIGEL      PHN
# 309           SAN SALVADOR     SAN SALVADOR      PHN
# 310                CATRILO          CATRILO      PHS
#
#         ÁREA ACTUACION RTV NOMBRE                 NOMBRE RTV   nombre  \
# 0                  SANTA FE NORTE  FAVIO TERENZIO VILLARRAZA    FAVIO
# 1                         LITORAL  FAVIO TERENZIO VILLARRAZA    FAVIO
# 4                  SANTA FE NORTE  FAVIO TERENZIO VILLARRAZA    FAVIO
# 5                SANTA FE ROSARIO            HERNAN STAMBUCK   HERNAN
# 6                 BA CENTRO-NORTE              ADRIAN AMIONE   ADRIAN
# ..                            ...                        ...      ...
# 306               EERR CENTRO-SUR          MARCOS ANZULOVICH   MARCOS
# 307                   BA NOROESTE      MARIA EUGENIA DUHALDE    MARIA
# 308  CORDOBA N.E. Y SANTA FE C.O.             HORACIO LOSANO  HORACIO
# 309               EERR CENTRO-SUR          MARCOS ANZULOVICH   MARCOS
# 310                      LA PAMPA              CLAUDIO SAENZ  CLAUDIO
#
#        apellido Distrito Area_Actuacion Nombre RTV/DTM e-Mail  Celular
# 0    VILLARRAZA      NaN            NaN    NaN     NaN     NaN     NaN
# 1    VILLARRAZA      NaN            NaN    NaN     NaN     NaN     NaN
# 4    VILLARRAZA      NaN            NaN    NaN     NaN     NaN     NaN
# 5      STAMBUCK      NaN            NaN    NaN     NaN     NaN     NaN
# 6        AMIONE      NaN            NaN    NaN     NaN     NaN     NaN
# ..          ...      ...            ...    ...     ...     ...     ...
# 306  ANZULOVICH      NaN            NaN    NaN     NaN     NaN     NaN
# 307     DUHALDE      NaN            NaN    NaN     NaN     NaN     NaN
# 308      LOSANO      NaN            NaN    NaN     NaN     NaN     NaN
# 309  ANZULOVICH      NaN            NaN    NaN     NaN     NaN     NaN
# 310       SAENZ      NaN            NaN    NaN     NaN     NaN     NaN
#
# [198 rows x 16 columns]

# %% [markdown]
# 198 registros siguen unmatched.

# %% [markdown]
# ##### Fuzzy Matching

# %%
from fuzzywuzzy import fuzz, process

def fuzzy_merge(df1, df2, key1, key2, threshold=90):
    """
    df1 is the left table to join
    df2 is the right table to join
    key1 is the key column of df1
    key2 is the key column of df2
    threshold is how close the matches should be to return a match, based on Levenshtein distance
    """
    s = df2[key2].tolist()
    
    # Encuentro el match -> m devuelve una serie de pandas: ['(NOMBRE, # VECES QUE LO ENCUENTRA)']
    m = df1[key1].apply(lambda x: process.extractOne(x, s, score_cutoff=threshold))
    
    # Obtengo el nombre de df2 - debo transformar m.
    
    # Step 1: Quito parentesis
    m_clean = m.astype(str).str.strip('()')

    # Step 2: Separo string entre nombre y # de veces que encuentra
    df_split = m_clean.str.split(', ', expand=True)

    # Step 3: Solo me interesa el nombre
    match = df_split[[0]].rename(columns={0: 'Name'})
    
    df1['matches'] = match['Name'] # solo me quedo el nombre
    
    return df1
# Out:
# /home/gugui/.local/lib/python3.10/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
# Creamos merged set
merged_RTV = fuzzy_merge(df_RTV, df_representantes_RTV, 'NOMBRE RTV', 'Nombre', threshold=60)
# Out:
# /tmp/ipykernel_415729/2459021407.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['matches'] = match['Name'] # solo me quedo el nombre

# %%
merged_RTV[merged_RTV['matches'].isnull()]
# Out:
# Empty DataFrame
# Columns: [DISTRIBUIDOR BASF, Provincia, localidad, Departamento / Partido, pedania, distrito, ÁREA ACTUACION RTV NOMBRE, NOMBRE RTV, nombre, apellido, matches]
# Index: []

# %%
# quitamos comillas
merged_RTV['matches'] = merged_RTV['matches'].str.replace("'"," ")

#  agregamos contacto
merged_RTV = merged_RTV.rename(columns={'matches': 'Nombre'})

# Limpiamos
merged_RTV['Nombre'] = merged_RTV['Nombre'].str.strip()
merged_RTV['Nombre'] = merged_RTV['Nombre'].str.replace(r'\s+', ' ', regex=True)
# Out:
# /tmp/ipykernel_415729/3529466315.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_RTV['matches'] = merged_RTV['matches'].str.replace("'"," ")

# %%
# Unimos tabla RTV
merged_RTV = pd.merge(merged_RTV, df_representantes_RTV, on = 'Nombre', how = 'left')

# Quitamos columnas adicionales
merged_RTV.drop(columns= ['nombre_y', 'apellido_y','NOMBRE RTV', 'Distrito', 'Area_Actuacion'], inplace= True)

# %% [markdown]
# #### DTM

# %%
# Creamos merged set
merged_DTM = fuzzy_merge(df_DTM, df_representantes_DTM, 'NOMBRE DTM ', 'Nombre', threshold=60)
# Out:
# /tmp/ipykernel_415729/2459021407.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['matches'] = match['Name'] # solo me quedo el nombre

# %%
merged_DTM[merged_DTM['matches'].isnull()]
# Out:
# Empty DataFrame
# Columns: [DISTRIBUIDOR BASF, Provincia, localidad, Departamento / Partido, pedania, distrito, AREA ACTUACION DTM, NOMBRE DTM , nombre, apellido, matches]
# Index: []

# %%
# quitamos comillas
merged_DTM['matches'] = merged_DTM['matches'].str.replace("'"," ")

#  agregamos contacto
merged_DTM = merged_DTM.rename(columns={'matches': 'Nombre'})

# Limpiamos
merged_DTM['Nombre'] = merged_DTM['Nombre'].str.strip()
merged_DTM['Nombre'] = merged_DTM['Nombre'].str.replace(r'\s+', ' ', regex=True)
# Out:
# /tmp/ipykernel_415729/1033637405.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_DTM['matches'] = merged_DTM['matches'].str.replace("'"," ")

# %%
# Unimos tabla RTV
merged_DTM = pd.merge(merged_DTM, df_representantes_DTM, on = 'Nombre', how = 'left')

# Quitamos columnas adicionales
merged_DTM.drop(columns= ['nombre_y', 'apellido_y','NOMBRE DTM ', 'Distrito', 'Area_Actuacion'], inplace= True)

# %%
merged_DTM
# Out:
#                       DISTRIBUIDOR BASF     Provincia  \
# 0                              SINER SA      SANTA FE
# 1                               FG AGRO    ENTRE RIOS
# 2                  MAS AGRO CENTRO S.A.       CORDOBA
# 3            TERRA VERDE AGROINSUMOS SA       CORDOBA
# 4    UNION AGRICOLA DE AVELLANEDA COOP.      SANTA FE
# ..                                  ...           ...
# 311                     RURAL CERES S.A  BUENOS AIRES
# 312                 LA CASA DEL AGRO SA       CORDOBA
# 313                 LA CASA DEL AGRO SA       CORDOBA
# 314                 LA CASA DEL AGRO SA       CORDOBA
# 315                       TECNOCAMPO SA       CORDOBA
#
#                      localidad Departamento / Partido          pedania  \
# 0                        CERES          SAN CRISTOBAL            CERES
# 1                    CONCORDIA              CONCORDIA        CONCORDIA
# 2    SANTA ROSA DE RIO PRIMERO            RIO PRIMERO       SANTA SOSA
# 3                  VILLA MARIA     GENERAL SAN MARTIN      VILLA MARIA
# 4              GUADALUPE NORTE       GENERAL OBLIGADO  GUADALUPE NORTE
# ..                         ...                    ...              ...
# 311                     TANDIL                 TANDIL           TANDIL
# 312              EL FUERTECITO              SAN JUSTO         ARROYITO
# 313                     MARULL              SAN JUSTO       CONCEPCION
# 314  SANTA ROSA DE RIO PRIMERO            RIO PRIMERO       SANTA SOSA
# 315                ALTA GRACIA            SANTA MARIA      ALTA GRACIA
#
#     distrito AREA ACTUACION DTM  nombre_x apellido_x  \
# 0    NOA-NEA     SANTA FE NORTE  MAURICIO     MUCHUT
# 1    NOA-NEA            LITORAL  MAURICIO     MUCHUT
# 2        PHC      CORDOBA NORTE    DANIEL       ULLA
# 3        PHC     CORDOBA CENTRO    SORAYA   MARITANO
# 4    NOA-NEA     SANTA FE NORTE  MAURICIO     MUCHUT
# ..       ...                ...       ...        ...
# 311      PHS         BA SUDESTE   FACUNDO   CAMERINI
# 312      PHC      CORDOBA NORTE    DANIEL       ULLA
# 313      PHC      CORDOBA NORTE    DANIEL       ULLA
# 314      PHC      CORDOBA NORTE    DANIEL       ULLA
# 315      PHC      CORDOBA NORTE    DANIEL       ULLA
#
#                          Nombre RTV/DTM                    e-Mail   \
# 0       MUCHUT MAURICIO ESTEBAN     DTM   mauricio.muchut@basf.com
# 1       MUCHUT MAURICIO ESTEBAN     DTM   mauricio.muchut@basf.com
# 2              ULLA DANIEL JOSE     DTM       daniel.ulla@basf.com
# 3               MARITANO SORAYA     DTM   soraya.maritano@basf.com
# 4       MUCHUT MAURICIO ESTEBAN     DTM   mauricio.muchut@basf.com
# ..                          ...     ...                        ...
# 311  CAMERINI ALEWAERTS FACUNDO     DTM  facundo.camerini@basf.com
# 312            ULLA DANIEL JOSE     DTM       daniel.ulla@basf.com
# 313            ULLA DANIEL JOSE     DTM       daniel.ulla@basf.com
# 314            ULLA DANIEL JOSE     DTM       daniel.ulla@basf.com
# 315            ULLA DANIEL JOSE     DTM       daniel.ulla@basf.com
#
#               Celular
# 0    +54 934 82296464
# 1    +54 934 82296464
# 2    +54 935 85070315
# 3    +54 935 34250007
# 4    +54 934 82296464
# ..                ...
# 311            ZZZZZZ
# 312  +54 935 85070315
# 313  +54 935 85070315
# 314  +54 935 85070315
# 315  +54 935 85070315
#
# [316 rows x 13 columns]

# %% [markdown]
# ---

# %% [markdown]
# ### Exportamos datasets listos

# %%
# Create the "processed" folder if it doesn't exist
#if not os.path.exists('../processed'):
#   os.makedirs('processed')

path = os.path.abspath('') + "/processed/"

# Export merged_DTM to CSV
merged_DTM.to_csv(path + 'merged_DTM.csv', index=False)

# Export merged_RTV to CSV
merged_RTV.to_csv(path + 'merged_RTV.csv', index=False)
